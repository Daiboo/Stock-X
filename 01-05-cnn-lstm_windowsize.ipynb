# %% [markdown]
# # Stock Market Prediction using CNN-LSTM model
# This project is about analysis of Stock Market and providing predictions to the stockholders.
#
# For this, we used CNN-LSTM approach to create a blank model, then use it to train on stock market data. Further implementation is discussed below...

# %% [markdown]
# # Data collect

# %% [markdown]
# Before preprocessing data, a function to fetch real-time stock data (using Alpha Vantage API) is made

# %%
key = "TV1WC9ANR799K1H1"

import requests
import csv
from tqdm import tqdm
import pandas as pd
def request_stock_price_list(symbol, size, token):
    q_string = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={}&outputsize={}&apikey={}'
    proxies = {
        "http": "http://127.0.0.1:7890",
        "https": "http://127.0.0.1:7890",
    }
    print("Retrieving stock price data from Alpha Vantage (This may take a while)...")
    r = requests.get(q_string.format(symbol, size, token), proxies=proxies)
    print("Data has been successfully downloaded...")
    date = []
    colnames = list(range(0, 5))
    df = pd.DataFrame(columns = colnames)
    print("Sorting the retrieved data into a dataframe...")
    for i in tqdm(r.json()['Time Series (Daily)'].keys()):
        date.append(i)
        row = pd.DataFrame.from_dict(r.json()['Time Series (Daily)'][i], orient='index').reset_index().T[1:]
        df = pd.concat([df, row], ignore_index=True)
    df.columns = ["Open", "High", "Low", "Close", "Volume"]
    df['Date'] = date
    return df

# %%
# cv1 = request_stock_price_list('600104.SHH', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHH.csv')

# %%
# cv1 = request_stock_price_list('000002.SHZ', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHZ.csv')

# %%
# cv1 = request_stock_price_list('TSCO.LON', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_LON.csv')

# %%
# cv1 = request_stock_price_list('SHOP.TRT', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_TRT.csv')

# %%
# cv1 = request_stock_price_list('RELIANCE.BSE', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_BSE.csv')

# %%
# UNCOMMENT THE CELL IF DATA IS NEEDED TO BE LOADED FOR 1ST TIME

# cv1 = request_stock_price_list('IBM', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data.csv')

# %% [markdown]
# # Training part

# %% [markdown]
# This part has 2 subparts: CNN and LSTM
#
# For CNN, the layers are created with sizes 64,128,64 with kernel size = 3. In every layer, TimeDistributed function is added to track the features for every temporal slice of data with respect to time. In between, MaxPooling layers are added.
#
# After that, it's passed to Bi-LSTM layers

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")


# 封装
class StockPredictor:
    def __init__(self,data_path,window_size=100):
        self.data_path = data_path      # 数据路径
        
        self.window_size = window_size    # 窗口大小
        self.train_X,self.test_X,self.train_Y,self.test_Y = self.__pressing_data(self.data_path)  # 第一步：数据预处理
        self.model = self.__construct_model()                                            # 第二步：模型
        self.history = None                                                       
        
    
    def __pressing_data(self,data_path,shuffle=True):
        window_size = self.window_size
        data = pd.read_csv(data_path, usecols=["Close"])
        data.reset_index(drop=True, inplace=True)
        data.fillna(data.mean(), inplace=True)

        close_column = data['Close']
        X = []
        Y = []
        for i in range(1 , len(close_column) - window_size -1 , 1):
            first = close_column[i]
            temp = []
            temp2 = []
            for j in range(window_size):
                temp.append((close_column[i + j] - first) / first)
            temp2.append((close_column[i + window_size] - first) / first)
            X.append(np.array(temp).reshape(window_size, 1))
            Y.append(np.array(temp2).reshape(1, 1))

        x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=shuffle)

        train_X = np.array(x_train)
        test_X = np.array(x_test)
        train_Y = np.array(y_train)
        test_Y = np.array(y_test)
        train_X = train_X.reshape(train_X.shape[0],1,window_size,1)
        test_X = test_X.reshape(test_X.shape[0],1,window_size,1)
        return train_X, test_X, train_Y, test_Y

    
    def __construct_model(self, dropout=0.5):
        window_size = self.window_size
        model = tf.keras.Sequential()
        # Creating the Neural Network model here...
        # CNN layers
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, window_size, 1))))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Flatten()))
        # model.add(Dense(5, kernel_regularizer=L2(0.01)))
        # LSTM layers
        model.add(Bidirectional(LSTM(100, return_sequences=True)))
        model.add(Dropout(dropout))
        model.add(Bidirectional(LSTM(100, return_sequences=False)))
        model.add(Dropout(dropout))
        #Final layers
        model.add(Dense(1, activation='linear'))
        model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
        return model

    def fit(self, epochs=40, batch_size=40, verbose=1, shuffle=True):
        # 训练模型
        self.history = self.model.fit(self.train_X, self.train_Y, epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=shuffle, validation_data=(self.test_X, self.test_Y))
        
    
    def plot(self):
        # 绘制训练过程
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mse'], label='train mse')
        plt.plot(self.history.history['val_mse'], label='val mse')
        plt.xlabel("epoch")
        plt.ylabel("MSE")
        plt.legend()
        plt.show()
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mae'], label='train mae')
        plt.plot(self.history.history['val_mae'], label='val mae')
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.show()
        
    def summary(self):
        self.model.summary()
    
    def evaluate(self):
        return self.model.evaluate(self.test_X, self.test_Y)

    def __predict_handle(self,data_path,train_X,test_X,test_Y):
        predicted_pre  = self.model.predict(test_X)   # 预测
        test_label_pre = test_Y.reshape(-1,1)       # 真实值
        predicted_pre = np.array(predicted_pre[:,0]).reshape(-1,1)
        
        close_column = pd.read_csv(data_path, usecols=["Close"])
        close_column.reset_index(drop=True, inplace=True)
        close_column.fillna(close_column.mean(), inplace=True)
        close_column = close_column['Close']
        
        test_label_raw = np.zeros(len(test_label_pre))
        predicted_raw = np.zeros(len(predicted_pre))
        len_t = len(train_X)
        for j in range(len_t , len_t + len(test_X)):
            temp = close_column[j]
            test_label_raw[j - len_t] = test_label_pre[j - len_t] * temp + temp
            predicted_raw[j - len_t] = predicted_pre[j - len_t] * temp + temp

        plt.figure(figsize=(15, 6))
        plt.plot(predicted_raw, color = 'green', label = 'Predicted  Stock Price')
        plt.plot(test_label_raw, color = 'red', label = 'Real Stock Price')
        plt.title(' Stock Price Prediction')
        plt.xlabel('Time')
        plt.ylabel(' Stock Price')
        plt.legend()
        plt.show()

    def predict(self):
        self.__predict_handle(self.data_path,self.train_X,self.test_X,self.test_Y)

    
    def predict_others(self, data_paths):
        train_X, test_X, train_Y, test_Y = self.__pressing_data(data_paths,shuffle=False)
        self.__predict_handle(data_paths,train_X,test_X,test_Y)
        return self.model.evaluate(test_X, test_Y)
        


    def save(self, path):
        self.model.save(path)

    def load(self, path):
        self.model = tf.keras.models.load_model(path)

# %% [markdown]
# # 训练部分

# %%
data_paths = ["data/NASDAQ/abe.us.txt","data/data_LON.csv", "data/data_SHH.csv", "data/data_SHZ.csv","data/data_BSE.csv"] 
train_mse = []
test_mes = []
for data_path in data_paths:
    stock = StockPredictor(data_path,window_size=50)
    stock.fit()
    train_mse.append(stock.evaluate()[1])
    test_mes.append(stock.predict_others('./data/data.csv')[1])
    stock.save('model/' + data_path.split('.')[0].split('/')[1] + '.h5')
# Out:
# Epoch 1/40
# 63/63 [==============================] - 5s 19ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0610 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0359
# Epoch 2/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0350 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0303
# Epoch 3/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0312 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0381
# Epoch 4/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0318 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0327
# Epoch 5/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0296 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0315
# Epoch 6/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0305 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0281
# Epoch 7/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0290 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0299
# Epoch 8/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0282 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0279
# Epoch 9/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0270 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0289
# Epoch 10/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0275 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0294
# Epoch 11/40
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0280 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0289
# Epoch 12/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0282 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0292
# Epoch 13/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0285 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0289
# Epoch 14/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0266 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0288
# Epoch 15/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0288 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0302
# Epoch 16/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0278 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0275
# Epoch 17/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0263 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0286
# Epoch 18/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0262 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0271
# Epoch 19/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0263 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0275
# Epoch 20/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0266 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0262
# Epoch 21/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0267 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0282
# Epoch 22/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0255 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0312
# Epoch 23/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0274 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0270
# Epoch 24/40
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0255 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0266
# Epoch 25/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0258 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0281
# Epoch 26/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0252 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0268
# Epoch 27/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0266 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0270
# Epoch 28/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0255 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0338
# Epoch 29/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0272 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0266
# Epoch 30/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0252 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0257
# Epoch 31/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0251 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0265
# Epoch 32/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0243 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0264
# Epoch 33/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0247 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0261
# Epoch 34/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0239 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0264
# Epoch 35/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0245 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0272
# Epoch 36/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0253
# Epoch 37/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0242 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0264
# Epoch 38/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0248 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0272
# Epoch 39/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0242 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0258
# Epoch 40/40
# 63/63 [==============================] - 0s 7ms/step - loss: 9.4829e-04 - mse: 9.4829e-04 - mae: 0.0234 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0306
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0306
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0466
# Epoch 1/40
# 95/95 [==============================] - 5s 14ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0577 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0341
# Epoch 2/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0352 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0272
# Epoch 3/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0317 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0271
# Epoch 4/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0308 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0276
# Epoch 5/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0296 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0272
# Epoch 6/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0284 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0272
# Epoch 7/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0300 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0257
# Epoch 8/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0300 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0250
# Epoch 9/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0279 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0261
# Epoch 10/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0285 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0261
# Epoch 11/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0290 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0242
# Epoch 12/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0289 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0249
# Epoch 13/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0286 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0254
# Epoch 14/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0281 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0254
# Epoch 15/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0272 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0262
# Epoch 16/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0296 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0241
# Epoch 17/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0276 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0257
# Epoch 18/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0272 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0326
# Epoch 19/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0273 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0242
# Epoch 20/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0266 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0250
# Epoch 21/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0283 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0251
# Epoch 22/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0275 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0252
# Epoch 23/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0262 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0242
# Epoch 24/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0259 - val_loss: 9.8536e-04 - val_mse: 9.8536e-04 - val_mae: 0.0234
# Epoch 25/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0256 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0246
# Epoch 26/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0257 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0239
# Epoch 27/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0257 - val_loss: 9.9261e-04 - val_mse: 9.9261e-04 - val_mae: 0.0235
# Epoch 28/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0260 - val_loss: 9.8227e-04 - val_mse: 9.8227e-04 - val_mae: 0.0236
# Epoch 29/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0258 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0245
# Epoch 30/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0253 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0245
# Epoch 31/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0245 - val_loss: 9.7149e-04 - val_mse: 9.7149e-04 - val_mae: 0.0236
# Epoch 32/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0258 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0247
# Epoch 33/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0241 - val_loss: 9.8079e-04 - val_mse: 9.8079e-04 - val_mae: 0.0239
# Epoch 34/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0273
# Epoch 35/40
# 95/95 [==============================] - 1s 8ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0254 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0247
# Epoch 36/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0244 - val_loss: 9.5044e-04 - val_mse: 9.5044e-04 - val_mae: 0.0231
# Epoch 37/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0245 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0241
# Epoch 38/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0242 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0246
# Epoch 39/40
# 95/95 [==============================] - 1s 7ms/step - loss: 9.6506e-04 - mse: 9.6506e-04 - mae: 0.0237 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0250
# Epoch 40/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0237 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0266
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0266
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0438
# Epoch 1/40
# 87/87 [==============================] - 5s 16ms/step - loss: 0.0198 - mse: 0.0198 - mae: 0.0992 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0544
# Epoch 2/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0564 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0513
# Epoch 3/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0508 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0507
# Epoch 4/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0489 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0493
# Epoch 5/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0485 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0510
# Epoch 6/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0497 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0457
# Epoch 7/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0432 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0512
# Epoch 8/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0460 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0492
# Epoch 9/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0463 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0478
# Epoch 10/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0455 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0529
# Epoch 11/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0467 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0435
# Epoch 12/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0466 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0444
# Epoch 13/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0426 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0439
# Epoch 14/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0434 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0452
# Epoch 15/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0422 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0460
# Epoch 16/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0431 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0460
# Epoch 17/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0421 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0438
# Epoch 18/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0423 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0422
# Epoch 19/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0411 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0464
# Epoch 20/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0406 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0451
# Epoch 21/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0412 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0457
# Epoch 22/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0441 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0433
# Epoch 23/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0406 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0436
# Epoch 24/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0387 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0424
# Epoch 25/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0397 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0421
# Epoch 26/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0389 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0423
# Epoch 27/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0392 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0427
# Epoch 28/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0401 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0463
# Epoch 29/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0390 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0445
# Epoch 30/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0390 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0439
# Epoch 31/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0384 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0447
# Epoch 32/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0397 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0426
# Epoch 33/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0381 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0434
# Epoch 34/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0374 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0421
# Epoch 35/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0375 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0414
# Epoch 36/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0367 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0407
# Epoch 37/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0372 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0424
# Epoch 38/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0364 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0426
# Epoch 39/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0378 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0417
# Epoch 40/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0359 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0408
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0408
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0419
# Epoch 1/40
# 87/87 [==============================] - 5s 16ms/step - loss: 0.0297 - mse: 0.0297 - mae: 0.1033 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0633
# Epoch 2/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0667 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0570
# Epoch 3/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0117 - mse: 0.0117 - mae: 0.0660 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0522
# Epoch 4/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0605 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0516
# Epoch 5/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0554 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0574
# Epoch 6/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0578 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0492
# Epoch 7/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0563 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0483
# Epoch 8/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0524 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0514
# Epoch 9/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0550 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0538
# Epoch 10/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0530 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0542
# Epoch 11/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0587 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0483
# Epoch 12/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0541 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0493
# Epoch 13/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0521 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0540
# Epoch 14/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0524 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0470
# Epoch 15/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0514 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0492
# Epoch 16/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0512 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0554
# Epoch 17/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0524 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0461
# Epoch 18/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0505 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0520
# Epoch 19/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0528 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0513
# Epoch 20/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0511 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0474
# Epoch 21/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0488 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0515
# Epoch 22/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0482 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0476
# Epoch 23/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0500 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0492
# Epoch 24/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0506 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0497
# Epoch 25/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0489 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0534
# Epoch 26/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0501 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0466
# Epoch 27/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0471 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0490
# Epoch 28/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0482 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0457
# Epoch 29/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0469 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0453
# Epoch 30/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0483 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0486
# Epoch 31/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0479 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0453
# Epoch 32/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0486 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0465
# Epoch 33/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0465 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0453
# Epoch 34/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0470 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0493
# Epoch 35/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0454 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0470
# Epoch 36/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0444 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0442
# Epoch 37/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0451 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0448
# Epoch 38/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0450 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0465
# Epoch 39/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0444 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0458
# Epoch 40/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0447 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0444
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0444
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0433
# Epoch 1/40
# 93/93 [==============================] - 5s 16ms/step - loss: 0.0229 - mse: 0.0229 - mae: 0.0882 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0508
# Epoch 2/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0520 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0463
# Epoch 3/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0469 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0465
# Epoch 4/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0474 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0418
# Epoch 5/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0476 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0404
# Epoch 6/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0447 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0418
# Epoch 7/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0438 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0404
# Epoch 8/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0424 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0427
# Epoch 9/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0436 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0431
# Epoch 10/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0441 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0399
# Epoch 11/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0415 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0388
# Epoch 12/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0428 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0398
# Epoch 13/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0402 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0446
# Epoch 14/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0452 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0404
# Epoch 15/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0418 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0393
# Epoch 16/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0401 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0509
# Epoch 17/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0424 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0380
# Epoch 18/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0408 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0377
# Epoch 19/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0397 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0395
# Epoch 20/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0391 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0379
# Epoch 21/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0388 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0395
# Epoch 22/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0397 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0454
# Epoch 23/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0416 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0404
# Epoch 24/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0418 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0385
# Epoch 25/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0367 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0391
# Epoch 26/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0399 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0388
# Epoch 27/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0398 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0391
# Epoch 28/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0393 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0382
# Epoch 29/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0384 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0416
# Epoch 30/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0367 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0406
# Epoch 31/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0403 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0383
# Epoch 32/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0374 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0420
# Epoch 33/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0409 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0380
# Epoch 34/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0383 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0405
# Epoch 35/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0402 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0396
# Epoch 36/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0379 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0364
# Epoch 37/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0394 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0427
# Epoch 38/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0389 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0411
# Epoch 39/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0382 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0431
# Epoch 40/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0384 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0379
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0379
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0451

# %%
# print(train_mse)
# 以保留四位小数打印
print(np.round(train_mse, 5))
print(np.round(np.mean(train_mse),5))
# Out:
# [0.00164 0.00129 0.00308 0.0037  0.00298]
# 0.00254

# %%
# print(test_mes)
# 以保留四位小数打印
print(np.round(test_mes, 5))
print(np.round(np.mean(test_mes),5))
# Out:
# [0.00375 0.00352 0.00312 0.00348 0.00362]
# 0.0035

# %%
# print(test_mes)
# 以保留四位小数打印
print(np.round(test_mes, 5))
print(np.round(np.mean(test_mes),5))
# Out:
# [0.00375 0.00352 0.00312 0.00348 0.00362]
# 0.0035
