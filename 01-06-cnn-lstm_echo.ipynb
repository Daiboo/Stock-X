# %% [markdown]
# # Stock Market Prediction using CNN-LSTM model
# This project is about analysis of Stock Market and providing predictions to the stockholders.
#
# For this, we used CNN-LSTM approach to create a blank model, then use it to train on stock market data. Further implementation is discussed below...

# %% [markdown]
# # Data collect

# %% [markdown]
# Before preprocessing data, a function to fetch real-time stock data (using Alpha Vantage API) is made

# %%
key = "TV1WC9ANR799K1H1"

import requests
import csv
from tqdm import tqdm
import pandas as pd
def request_stock_price_list(symbol, size, token):
    q_string = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={}&outputsize={}&apikey={}'
    proxies = {
        "http": "http://127.0.0.1:7890",
        "https": "http://127.0.0.1:7890",
    }
    print("Retrieving stock price data from Alpha Vantage (This may take a while)...")
    r = requests.get(q_string.format(symbol, size, token), proxies=proxies)
    print("Data has been successfully downloaded...")
    date = []
    colnames = list(range(0, 5))
    df = pd.DataFrame(columns = colnames)
    print("Sorting the retrieved data into a dataframe...")
    for i in tqdm(r.json()['Time Series (Daily)'].keys()):
        date.append(i)
        row = pd.DataFrame.from_dict(r.json()['Time Series (Daily)'][i], orient='index').reset_index().T[1:]
        df = pd.concat([df, row], ignore_index=True)
    df.columns = ["Open", "High", "Low", "Close", "Volume"]
    df['Date'] = date
    return df

# %%
# cv1 = request_stock_price_list('600104.SHH', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHH.csv')

# %%
# cv1 = request_stock_price_list('000002.SHZ', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHZ.csv')

# %%
# cv1 = request_stock_price_list('TSCO.LON', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_LON.csv')

# %%
# cv1 = request_stock_price_list('SHOP.TRT', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_TRT.csv')

# %%
# cv1 = request_stock_price_list('RELIANCE.BSE', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_BSE.csv')

# %%
# UNCOMMENT THE CELL IF DATA IS NEEDED TO BE LOADED FOR 1ST TIME

# cv1 = request_stock_price_list('IBM', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data.csv')

# %% [markdown]
# # Training part

# %% [markdown]
# This part has 2 subparts: CNN and LSTM
#
# For CNN, the layers are created with sizes 64,128,64 with kernel size = 3. In every layer, TimeDistributed function is added to track the features for every temporal slice of data with respect to time. In between, MaxPooling layers are added.
#
# After that, it's passed to Bi-LSTM layers

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")


# 封装
class StockPredictor:
    def __init__(self,data_path,window_size=100):
        self.data_path = data_path      # 数据路径
        
        self.window_size = window_size    # 窗口大小
        self.train_X,self.test_X,self.train_Y,self.test_Y = self.__pressing_data(self.data_path)  # 第一步：数据预处理
        self.model = self.__construct_model()                                            # 第二步：模型
        self.history = None                                                       
        
    
    def __pressing_data(self,data_path,shuffle=True):
        window_size = self.window_size
        data = pd.read_csv(data_path, usecols=["Close"])
        data.reset_index(drop=True, inplace=True)
        data.fillna(data.mean(), inplace=True)

        close_column = data['Close']
        X = []
        Y = []
        for i in range(1 , len(close_column) - window_size -1 , 1):
            first = close_column[i]
            temp = []
            temp2 = []
            for j in range(window_size):
                temp.append((close_column[i + j] - first) / first)
            temp2.append((close_column[i + window_size] - first) / first)
            X.append(np.array(temp).reshape(window_size, 1))
            Y.append(np.array(temp2).reshape(1, 1))

        x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=shuffle)

        train_X = np.array(x_train)
        test_X = np.array(x_test)
        train_Y = np.array(y_train)
        test_Y = np.array(y_test)
        train_X = train_X.reshape(train_X.shape[0],1,window_size,1)
        test_X = test_X.reshape(test_X.shape[0],1,window_size,1)
        return train_X, test_X, train_Y, test_Y

    
    def __construct_model(self, dropout=0.5):
        window_size = self.window_size
        model = tf.keras.Sequential()
        # Creating the Neural Network model here...
        # CNN layers
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, window_size, 1))))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Flatten()))
        model.add(Dense(5, kernel_regularizer=L2(0.015)))
        # LSTM layers
        model.add(Bidirectional(LSTM(100, return_sequences=True)))
        model.add(Dropout(dropout))
        model.add(Bidirectional(LSTM(100, return_sequences=False)))
        model.add(Dropout(dropout))
        #Final layers
        model.add(Dense(1, activation='linear'))
        model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
        return model

    def fit(self, epochs=40, batch_size=40, verbose=1, shuffle=True):
        # 训练模型
        self.history = self.model.fit(self.train_X, self.train_Y, epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=shuffle, validation_data=(self.test_X, self.test_Y))
        
    
    def plot(self):
        # 绘制训练过程
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mse'], label='train mse')
        plt.plot(self.history.history['val_mse'], label='val mse')
        plt.xlabel("epoch")
        plt.ylabel("MSE")
        plt.legend()
        plt.show()
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mae'], label='train mae')
        plt.plot(self.history.history['val_mae'], label='val mae')
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.show()
        
    def summary(self):
        self.model.summary()
    
    def evaluate(self):
        return self.model.evaluate(self.test_X, self.test_Y)

    def __predict_handle(self,data_path,train_X,test_X,test_Y):
        predicted_pre  = self.model.predict(test_X)   # 预测
        test_label_pre = test_Y.reshape(-1,1)       # 真实值
        predicted_pre = np.array(predicted_pre[:,0]).reshape(-1,1)
        
        close_column = pd.read_csv(data_path, usecols=["Close"])
        close_column.reset_index(drop=True, inplace=True)
        close_column.fillna(close_column.mean(), inplace=True)
        close_column = close_column['Close']
        
        test_label_raw = np.zeros(len(test_label_pre))
        predicted_raw = np.zeros(len(predicted_pre))
        len_t = len(train_X)
        for j in range(len_t , len_t + len(test_X)):
            temp = close_column[j]
            test_label_raw[j - len_t] = test_label_pre[j - len_t] * temp + temp
            predicted_raw[j - len_t] = predicted_pre[j - len_t] * temp + temp

        plt.figure(figsize=(15, 6))
        plt.plot(predicted_raw, color = 'green', label = 'Predicted  Stock Price')
        plt.plot(test_label_raw, color = 'red', label = 'Real Stock Price')
        plt.title(' Stock Price Prediction')
        plt.xlabel('Time')
        plt.ylabel(' Stock Price')
        plt.legend()
        plt.show()

    def predict(self):
        self.__predict_handle(self.data_path,self.train_X,self.test_X,self.test_Y)

    
    def predict_others(self, data_paths):
        train_X, test_X, train_Y, test_Y = self.__pressing_data(data_paths,shuffle=False)
        self.__predict_handle(data_paths,train_X,test_X,test_Y)
        return self.model.evaluate(test_X, test_Y)
        


    def save(self, path):
        self.model.save(path)

    def load(self, path):
        self.model = tf.keras.models.load_model(path)

# %% [markdown]
# # 训练部分

# %%
data_paths = ["data/NASDAQ/abe.us.txt","data/data_LON.csv", "data/data_SHH.csv", "data/data_SHZ.csv","data/data_BSE.csv"] 
train_mse = []
test_mes = []
for data_path in data_paths:
    stock = StockPredictor(data_path,window_size=50)
    stock.fit(epochs=50)
    stock.plot()
    train_mse.append(stock.evaluate()[1])
    
    test_mes.append(stock.predict_others('./data/data.csv')[1])
    stock.save('model/' + data_path.split('.')[0].split('/')[1] + '.h5')
# Out:
# Epoch 1/50
# 63/63 [==============================] - 5s 18ms/step - loss: 0.1195 - mse: 0.0076 - mae: 0.0631 - val_loss: 0.0400 - val_mse: 0.0031 - val_mae: 0.0412
# Epoch 2/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0291 - mse: 0.0026 - mae: 0.0379 - val_loss: 0.0097 - val_mse: 0.0022 - val_mae: 0.0351
# Epoch 3/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0076 - mse: 0.0023 - mae: 0.0357 - val_loss: 0.0034 - val_mse: 0.0019 - val_mae: 0.0312
# Epoch 4/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0030 - mse: 0.0019 - mae: 0.0326 - val_loss: 0.0025 - val_mse: 0.0021 - val_mae: 0.0340
# Epoch 5/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0025 - mse: 0.0021 - mae: 0.0330 - val_loss: 0.0019 - val_mse: 0.0017 - val_mae: 0.0293
# Epoch 6/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0021 - mse: 0.0018 - mae: 0.0316 - val_loss: 0.0019 - val_mse: 0.0017 - val_mae: 0.0294
# Epoch 7/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0016 - mae: 0.0297 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0279
# Epoch 8/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0021 - mse: 0.0019 - mae: 0.0324 - val_loss: 0.0022 - val_mse: 0.0021 - val_mae: 0.0341
# Epoch 9/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0020 - mse: 0.0019 - mae: 0.0317 - val_loss: 0.0017 - val_mse: 0.0015 - val_mae: 0.0286
# Epoch 10/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0301 - val_loss: 0.0019 - val_mse: 0.0018 - val_mae: 0.0316
# Epoch 11/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0300 - val_loss: 0.0021 - val_mse: 0.0020 - val_mae: 0.0337
# Epoch 12/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0019 - mse: 0.0018 - mae: 0.0314 - val_loss: 0.0017 - val_mse: 0.0016 - val_mae: 0.0285
# Epoch 13/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0293 - val_loss: 0.0017 - val_mse: 0.0016 - val_mae: 0.0285
# Epoch 14/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0284 - val_loss: 0.0018 - val_mse: 0.0017 - val_mae: 0.0307
# Epoch 15/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0300 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0271
# Epoch 16/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0304 - val_loss: 0.0018 - val_mse: 0.0017 - val_mae: 0.0307
# Epoch 17/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0283 - val_loss: 0.0018 - val_mse: 0.0017 - val_mae: 0.0304
# Epoch 18/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0019 - mse: 0.0018 - mae: 0.0308 - val_loss: 0.0018 - val_mse: 0.0017 - val_mae: 0.0295
# Epoch 19/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0017 - mse: 0.0015 - mae: 0.0289 - val_loss: 0.0016 - val_mse: 0.0014 - val_mae: 0.0270
# Epoch 20/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0299 - val_loss: 0.0021 - val_mse: 0.0020 - val_mae: 0.0329
# Epoch 21/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0018 - mse: 0.0016 - mae: 0.0298 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0274
# Epoch 22/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0286 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0263
# Epoch 23/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0289 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0264
# Epoch 24/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0280 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0268
# Epoch 25/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0277 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0261
# Epoch 26/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0304 - val_loss: 0.0017 - val_mse: 0.0016 - val_mae: 0.0289
# Epoch 27/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0279 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0283
# Epoch 28/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0280 - val_loss: 0.0020 - val_mse: 0.0019 - val_mae: 0.0322
# Epoch 29/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0289 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0280
# Epoch 30/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0290 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0273
# Epoch 31/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0282 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0272
# Epoch 32/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0289 - val_loss: 0.0017 - val_mse: 0.0016 - val_mae: 0.0290
# Epoch 33/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0279 - val_loss: 0.0017 - val_mse: 0.0016 - val_mae: 0.0283
# Epoch 34/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0284 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0269
# Epoch 35/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0280 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0276
# Epoch 36/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0271 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0278
# Epoch 37/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0287 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0269
# Epoch 38/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0017 - mse: 0.0015 - mae: 0.0289 - val_loss: 0.0019 - val_mse: 0.0018 - val_mae: 0.0329
# Epoch 39/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0017 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0259
# Epoch 40/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0278 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0257
# Epoch 41/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0274 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0280
# Epoch 42/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0277 - val_loss: 0.0019 - val_mse: 0.0018 - val_mae: 0.0320
# Epoch 43/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0269 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0284
# Epoch 44/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0271 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0262
# Epoch 45/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0275 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0273
# Epoch 46/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0279 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0283
# Epoch 47/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0267 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0282
# Epoch 48/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0276 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0263
# Epoch 49/50
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0268 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0268
# Epoch 50/50
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0270 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0261
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0261
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0033 - mse: 0.0032 - mae: 0.0416
# Epoch 1/50
# 95/95 [==============================] - 4s 13ms/step - loss: 0.1028 - mse: 0.0063 - mae: 0.0590 - val_loss: 0.0193 - val_mse: 0.0026 - val_mae: 0.0374
# Epoch 2/50
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0129 - mse: 0.0024 - mae: 0.0357 - val_loss: 0.0034 - val_mse: 0.0019 - val_mae: 0.0322
# Epoch 3/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0031 - mse: 0.0020 - mae: 0.0334 - val_loss: 0.0021 - val_mse: 0.0018 - val_mae: 0.0319
# Epoch 4/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0022 - mse: 0.0019 - mae: 0.0322 - val_loss: 0.0016 - val_mse: 0.0014 - val_mae: 0.0273
# Epoch 5/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0020 - mse: 0.0018 - mae: 0.0309 - val_loss: 0.0018 - val_mse: 0.0016 - val_mae: 0.0300
# Epoch 6/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0021 - mse: 0.0019 - mae: 0.0322 - val_loss: 0.0017 - val_mse: 0.0015 - val_mae: 0.0281
# Epoch 7/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0019 - mse: 0.0017 - mae: 0.0304 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0289
# Epoch 8/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0019 - mse: 0.0017 - mae: 0.0303 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0268
# Epoch 9/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0302 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0261
# Epoch 10/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0294 - val_loss: 0.0016 - val_mse: 0.0015 - val_mae: 0.0281
# Epoch 11/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0292 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0267
# Epoch 12/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0303 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0266
# Epoch 13/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0293 - val_loss: 0.0017 - val_mse: 0.0015 - val_mae: 0.0294
# Epoch 14/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0301 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0273
# Epoch 15/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0286 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0260
# Epoch 16/50
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0302 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0249
# Epoch 17/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0289 - val_loss: 0.0020 - val_mse: 0.0019 - val_mae: 0.0323
# Epoch 18/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0301 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0249
# Epoch 19/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0287 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0261
# Epoch 20/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0018 - mse: 0.0017 - mae: 0.0305 - val_loss: 0.0014 - val_mse: 0.0012 - val_mae: 0.0258
# Epoch 21/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0281 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0251
# Epoch 22/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0290 - val_loss: 0.0018 - val_mse: 0.0017 - val_mae: 0.0308
# Epoch 23/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0286 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0254
# Epoch 24/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0288 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0270
# Epoch 25/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0278 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0254
# Epoch 26/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0283 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0255
# Epoch 27/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0281 - val_loss: 0.0012 - val_mse: 0.0011 - val_mae: 0.0246
# Epoch 28/50
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0279 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0259
# Epoch 29/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0282 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0262
# Epoch 30/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0017 - mse: 0.0016 - mae: 0.0298 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0246
# Epoch 31/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0280 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0271
# Epoch 32/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0280 - val_loss: 0.0012 - val_mse: 0.0011 - val_mae: 0.0246
# Epoch 33/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0276 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0253
# Epoch 34/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0278 - val_loss: 0.0012 - val_mse: 0.0011 - val_mae: 0.0245
# Epoch 35/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0277 - val_loss: 0.0014 - val_mse: 0.0013 - val_mae: 0.0264
# Epoch 36/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0276 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0253
# Epoch 37/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0269 - val_loss: 0.0012 - val_mse: 0.0011 - val_mae: 0.0245
# Epoch 38/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0270 - val_loss: 0.0018 - val_mse: 0.0017 - val_mae: 0.0305
# Epoch 39/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0280 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0255
# Epoch 40/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0282 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0266
# Epoch 41/50
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0279 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0246
# Epoch 42/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0276 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0250
# Epoch 43/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0273 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0280
# Epoch 44/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0276 - val_loss: 0.0015 - val_mse: 0.0014 - val_mae: 0.0278
# Epoch 45/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0016 - mse: 0.0015 - mae: 0.0287 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0261
# Epoch 46/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0265 - val_loss: 0.0013 - val_mse: 0.0012 - val_mae: 0.0258
# Epoch 47/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0271 - val_loss: 0.0012 - val_mse: 0.0011 - val_mae: 0.0247
# Epoch 48/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0014 - mse: 0.0013 - mae: 0.0268 - val_loss: 0.0012 - val_mse: 0.0011 - val_mae: 0.0246
# Epoch 49/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0013 - mse: 0.0012 - mae: 0.0263 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0264
# Epoch 50/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0015 - mse: 0.0014 - mae: 0.0283 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0247
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0247
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0035 - mse: 0.0034 - mae: 0.0428
# Epoch 1/50
# 87/87 [==============================] - 5s 18ms/step - loss: 0.1226 - mse: 0.0227 - mae: 0.1009 - val_loss: 0.0295 - val_mse: 0.0068 - val_mae: 0.0621
# Epoch 2/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0232 - mse: 0.0077 - mae: 0.0617 - val_loss: 0.0096 - val_mse: 0.0052 - val_mae: 0.0529
# Epoch 3/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0088 - mse: 0.0055 - mae: 0.0529 - val_loss: 0.0062 - val_mse: 0.0047 - val_mae: 0.0486
# Epoch 4/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0070 - mse: 0.0058 - mae: 0.0526 - val_loss: 0.0055 - val_mse: 0.0047 - val_mae: 0.0482
# Epoch 5/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0056 - mse: 0.0048 - mae: 0.0508 - val_loss: 0.0081 - val_mse: 0.0075 - val_mae: 0.0594
# Epoch 6/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0065 - mse: 0.0058 - mae: 0.0539 - val_loss: 0.0053 - val_mse: 0.0048 - val_mae: 0.0498
# Epoch 7/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0051 - mse: 0.0046 - mae: 0.0489 - val_loss: 0.0047 - val_mse: 0.0042 - val_mae: 0.0477
# Epoch 8/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0055 - mse: 0.0051 - mae: 0.0505 - val_loss: 0.0044 - val_mse: 0.0040 - val_mae: 0.0438
# Epoch 9/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0052 - mse: 0.0048 - mae: 0.0491 - val_loss: 0.0043 - val_mse: 0.0038 - val_mae: 0.0437
# Epoch 10/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0056 - mse: 0.0052 - mae: 0.0511 - val_loss: 0.0062 - val_mse: 0.0058 - val_mae: 0.0548
# Epoch 11/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0051 - mse: 0.0046 - mae: 0.0489 - val_loss: 0.0043 - val_mse: 0.0039 - val_mae: 0.0432
# Epoch 12/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0047 - mse: 0.0044 - mae: 0.0478 - val_loss: 0.0041 - val_mse: 0.0037 - val_mae: 0.0423
# Epoch 13/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0049 - mse: 0.0045 - mae: 0.0481 - val_loss: 0.0059 - val_mse: 0.0056 - val_mae: 0.0508
# Epoch 14/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0051 - mse: 0.0048 - mae: 0.0490 - val_loss: 0.0051 - val_mse: 0.0047 - val_mae: 0.0494
# Epoch 15/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0046 - mse: 0.0043 - mae: 0.0466 - val_loss: 0.0041 - val_mse: 0.0037 - val_mae: 0.0425
# Epoch 16/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0053 - mse: 0.0050 - mae: 0.0499 - val_loss: 0.0041 - val_mse: 0.0038 - val_mae: 0.0430
# Epoch 17/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0048 - mse: 0.0044 - mae: 0.0474 - val_loss: 0.0042 - val_mse: 0.0039 - val_mae: 0.0428
# Epoch 18/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0043 - mse: 0.0040 - mae: 0.0454 - val_loss: 0.0041 - val_mse: 0.0038 - val_mae: 0.0439
# Epoch 19/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0046 - mse: 0.0043 - mae: 0.0462 - val_loss: 0.0039 - val_mse: 0.0036 - val_mae: 0.0419
# Epoch 20/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0044 - mse: 0.0041 - mae: 0.0457 - val_loss: 0.0038 - val_mse: 0.0035 - val_mae: 0.0411
# Epoch 21/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0045 - mse: 0.0042 - mae: 0.0468 - val_loss: 0.0050 - val_mse: 0.0047 - val_mae: 0.0528
# Epoch 22/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0047 - mse: 0.0044 - mae: 0.0475 - val_loss: 0.0042 - val_mse: 0.0039 - val_mae: 0.0438
# Epoch 23/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0044 - mse: 0.0041 - mae: 0.0453 - val_loss: 0.0040 - val_mse: 0.0038 - val_mae: 0.0428
# Epoch 24/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0041 - mse: 0.0038 - mae: 0.0440 - val_loss: 0.0040 - val_mse: 0.0037 - val_mae: 0.0435
# Epoch 25/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0043 - mse: 0.0040 - mae: 0.0455 - val_loss: 0.0042 - val_mse: 0.0039 - val_mae: 0.0447
# Epoch 26/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0044 - mse: 0.0041 - mae: 0.0445 - val_loss: 0.0039 - val_mse: 0.0036 - val_mae: 0.0421
# Epoch 27/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0040 - mse: 0.0037 - mae: 0.0440 - val_loss: 0.0040 - val_mse: 0.0037 - val_mae: 0.0437
# Epoch 28/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0042 - mse: 0.0039 - mae: 0.0448 - val_loss: 0.0038 - val_mse: 0.0036 - val_mae: 0.0421
# Epoch 29/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0038 - mse: 0.0035 - mae: 0.0428 - val_loss: 0.0041 - val_mse: 0.0039 - val_mae: 0.0458
# Epoch 30/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0040 - mse: 0.0038 - mae: 0.0446 - val_loss: 0.0043 - val_mse: 0.0040 - val_mae: 0.0447
# Epoch 31/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0041 - mse: 0.0038 - mae: 0.0448 - val_loss: 0.0036 - val_mse: 0.0034 - val_mae: 0.0407
# Epoch 32/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0039 - mse: 0.0037 - mae: 0.0443 - val_loss: 0.0037 - val_mse: 0.0034 - val_mae: 0.0414
# Epoch 33/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0039 - mse: 0.0036 - mae: 0.0441 - val_loss: 0.0040 - val_mse: 0.0038 - val_mae: 0.0432
# Epoch 34/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0038 - mse: 0.0036 - mae: 0.0431 - val_loss: 0.0044 - val_mse: 0.0042 - val_mae: 0.0473
# Epoch 35/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0042 - mse: 0.0039 - mae: 0.0461 - val_loss: 0.0043 - val_mse: 0.0041 - val_mae: 0.0474
# Epoch 36/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0039 - mse: 0.0037 - mae: 0.0441 - val_loss: 0.0036 - val_mse: 0.0034 - val_mae: 0.0406
# Epoch 37/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0037 - mse: 0.0034 - mae: 0.0421 - val_loss: 0.0037 - val_mse: 0.0035 - val_mae: 0.0409
# Epoch 38/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0038 - mse: 0.0036 - mae: 0.0442 - val_loss: 0.0036 - val_mse: 0.0034 - val_mae: 0.0408
# Epoch 39/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0036 - mse: 0.0034 - mae: 0.0421 - val_loss: 0.0038 - val_mse: 0.0035 - val_mae: 0.0418
# Epoch 40/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0039 - mse: 0.0036 - mae: 0.0438 - val_loss: 0.0036 - val_mse: 0.0034 - val_mae: 0.0419
# Epoch 41/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0034 - mse: 0.0031 - mae: 0.0406 - val_loss: 0.0037 - val_mse: 0.0034 - val_mae: 0.0414
# Epoch 42/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0038 - mse: 0.0035 - mae: 0.0440 - val_loss: 0.0036 - val_mse: 0.0033 - val_mae: 0.0405
# Epoch 43/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0034 - mse: 0.0032 - mae: 0.0405 - val_loss: 0.0035 - val_mse: 0.0032 - val_mae: 0.0400
# Epoch 44/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0035 - mse: 0.0033 - mae: 0.0418 - val_loss: 0.0035 - val_mse: 0.0033 - val_mae: 0.0404
# Epoch 45/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0037 - mse: 0.0035 - mae: 0.0437 - val_loss: 0.0036 - val_mse: 0.0034 - val_mae: 0.0412
# Epoch 46/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0035 - mse: 0.0033 - mae: 0.0420 - val_loss: 0.0037 - val_mse: 0.0035 - val_mae: 0.0417
# Epoch 47/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0035 - mse: 0.0033 - mae: 0.0419 - val_loss: 0.0035 - val_mse: 0.0033 - val_mae: 0.0406
# Epoch 48/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0033 - mse: 0.0031 - mae: 0.0410 - val_loss: 0.0036 - val_mse: 0.0033 - val_mae: 0.0407
# Epoch 49/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0033 - mse: 0.0031 - mae: 0.0409 - val_loss: 0.0035 - val_mse: 0.0032 - val_mae: 0.0403
# Epoch 50/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.0036 - mse: 0.0033 - mae: 0.0429 - val_loss: 0.0035 - val_mse: 0.0032 - val_mae: 0.0402
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0035 - mse: 0.0032 - mae: 0.0402
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0032 - mse: 0.0030 - mae: 0.0402
# Epoch 1/50
# 87/87 [==============================] - 5s 16ms/step - loss: 0.1269 - mse: 0.0293 - mae: 0.1102 - val_loss: 0.0327 - val_mse: 0.0090 - val_mae: 0.0686
# Epoch 2/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0322 - mse: 0.0155 - mae: 0.0756 - val_loss: 0.0147 - val_mse: 0.0092 - val_mae: 0.0671
# Epoch 3/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0132 - mse: 0.0088 - mae: 0.0630 - val_loss: 0.0099 - val_mse: 0.0074 - val_mae: 0.0621
# Epoch 4/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0114 - mse: 0.0091 - mae: 0.0616 - val_loss: 0.0082 - val_mse: 0.0065 - val_mae: 0.0595
# Epoch 5/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0102 - mse: 0.0086 - mae: 0.0590 - val_loss: 0.0079 - val_mse: 0.0066 - val_mae: 0.0589
# Epoch 6/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0099 - mse: 0.0086 - mae: 0.0590 - val_loss: 0.0065 - val_mse: 0.0054 - val_mae: 0.0557
# Epoch 7/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0096 - mse: 0.0086 - mae: 0.0600 - val_loss: 0.0056 - val_mse: 0.0046 - val_mae: 0.0496
# Epoch 8/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0094 - mse: 0.0085 - mae: 0.0573 - val_loss: 0.0072 - val_mse: 0.0063 - val_mae: 0.0566
# Epoch 9/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0101 - mse: 0.0093 - mae: 0.0610 - val_loss: 0.0057 - val_mse: 0.0048 - val_mae: 0.0499
# Epoch 10/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0069 - mse: 0.0062 - mae: 0.0532 - val_loss: 0.0072 - val_mse: 0.0064 - val_mae: 0.0570
# Epoch 11/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0102 - mse: 0.0094 - mae: 0.0606 - val_loss: 0.0053 - val_mse: 0.0046 - val_mae: 0.0484
# Epoch 12/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0091 - mse: 0.0084 - mae: 0.0548 - val_loss: 0.0051 - val_mse: 0.0045 - val_mae: 0.0470
# Epoch 13/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0095 - mse: 0.0088 - mae: 0.0573 - val_loss: 0.0066 - val_mse: 0.0060 - val_mae: 0.0584
# Epoch 14/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0075 - mse: 0.0068 - mae: 0.0546 - val_loss: 0.0056 - val_mse: 0.0050 - val_mae: 0.0521
# Epoch 15/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0091 - mse: 0.0085 - mae: 0.0559 - val_loss: 0.0049 - val_mse: 0.0043 - val_mae: 0.0487
# Epoch 16/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0080 - mse: 0.0075 - mae: 0.0554 - val_loss: 0.0085 - val_mse: 0.0080 - val_mae: 0.0650
# Epoch 17/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0071 - mse: 0.0066 - mae: 0.0538 - val_loss: 0.0052 - val_mse: 0.0047 - val_mae: 0.0504
# Epoch 18/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0063 - mse: 0.0058 - mae: 0.0520 - val_loss: 0.0052 - val_mse: 0.0047 - val_mae: 0.0506
# Epoch 19/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0071 - mse: 0.0066 - mae: 0.0540 - val_loss: 0.0050 - val_mse: 0.0045 - val_mae: 0.0503
# Epoch 20/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0059 - mse: 0.0054 - mae: 0.0500 - val_loss: 0.0046 - val_mse: 0.0041 - val_mae: 0.0466
# Epoch 21/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0073 - mse: 0.0068 - mae: 0.0528 - val_loss: 0.0045 - val_mse: 0.0040 - val_mae: 0.0456
# Epoch 22/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0068 - mse: 0.0063 - mae: 0.0524 - val_loss: 0.0052 - val_mse: 0.0048 - val_mae: 0.0516
# Epoch 23/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0063 - mse: 0.0059 - mae: 0.0501 - val_loss: 0.0048 - val_mse: 0.0044 - val_mae: 0.0472
# Epoch 24/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0065 - mse: 0.0061 - mae: 0.0531 - val_loss: 0.0048 - val_mse: 0.0044 - val_mae: 0.0486
# Epoch 25/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0068 - mse: 0.0063 - mae: 0.0525 - val_loss: 0.0046 - val_mse: 0.0042 - val_mae: 0.0471
# Epoch 26/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0073 - mse: 0.0069 - mae: 0.0535 - val_loss: 0.0058 - val_mse: 0.0054 - val_mae: 0.0539
# Epoch 27/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0063 - mse: 0.0059 - mae: 0.0517 - val_loss: 0.0046 - val_mse: 0.0041 - val_mae: 0.0476
# Epoch 28/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0064 - mse: 0.0060 - mae: 0.0504 - val_loss: 0.0050 - val_mse: 0.0045 - val_mae: 0.0480
# Epoch 29/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0054 - mse: 0.0050 - mae: 0.0499 - val_loss: 0.0056 - val_mse: 0.0052 - val_mae: 0.0547
# Epoch 30/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0080 - mse: 0.0076 - mae: 0.0568 - val_loss: 0.0051 - val_mse: 0.0047 - val_mae: 0.0506
# Epoch 31/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0071 - mse: 0.0067 - mae: 0.0524 - val_loss: 0.0044 - val_mse: 0.0040 - val_mae: 0.0453
# Epoch 32/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0064 - mse: 0.0059 - mae: 0.0521 - val_loss: 0.0056 - val_mse: 0.0051 - val_mae: 0.0519
# Epoch 33/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0059 - mse: 0.0055 - mae: 0.0494 - val_loss: 0.0046 - val_mse: 0.0042 - val_mae: 0.0465
# Epoch 34/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0058 - mae: 0.0508 - val_loss: 0.0049 - val_mse: 0.0045 - val_mae: 0.0467
# Epoch 35/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0058 - mae: 0.0516 - val_loss: 0.0050 - val_mse: 0.0046 - val_mae: 0.0516
# Epoch 36/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0068 - mse: 0.0064 - mae: 0.0530 - val_loss: 0.0046 - val_mse: 0.0041 - val_mae: 0.0473
# Epoch 37/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0055 - mae: 0.0520 - val_loss: 0.0051 - val_mse: 0.0047 - val_mae: 0.0483
# Epoch 38/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0061 - mse: 0.0057 - mae: 0.0508 - val_loss: 0.0045 - val_mse: 0.0041 - val_mae: 0.0470
# Epoch 39/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0055 - mse: 0.0051 - mae: 0.0494 - val_loss: 0.0068 - val_mse: 0.0063 - val_mae: 0.0602
# Epoch 40/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0056 - mae: 0.0527 - val_loss: 0.0049 - val_mse: 0.0045 - val_mae: 0.0488
# Epoch 41/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0057 - mse: 0.0053 - mae: 0.0498 - val_loss: 0.0063 - val_mse: 0.0059 - val_mae: 0.0587
# Epoch 42/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0058 - mse: 0.0054 - mae: 0.0513 - val_loss: 0.0067 - val_mse: 0.0063 - val_mae: 0.0539
# Epoch 43/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0067 - mse: 0.0063 - mae: 0.0556 - val_loss: 0.0043 - val_mse: 0.0039 - val_mae: 0.0445
# Epoch 44/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0061 - mse: 0.0057 - mae: 0.0506 - val_loss: 0.0043 - val_mse: 0.0039 - val_mae: 0.0448
# Epoch 45/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0056 - mse: 0.0052 - mae: 0.0491 - val_loss: 0.0043 - val_mse: 0.0039 - val_mae: 0.0456
# Epoch 46/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0059 - mse: 0.0055 - mae: 0.0512 - val_loss: 0.0045 - val_mse: 0.0041 - val_mae: 0.0466
# Epoch 47/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0048 - mae: 0.0487 - val_loss: 0.0053 - val_mse: 0.0049 - val_mae: 0.0534
# Epoch 48/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0049 - mse: 0.0045 - mae: 0.0483 - val_loss: 0.0045 - val_mse: 0.0041 - val_mae: 0.0447
# Epoch 49/50
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0048 - mae: 0.0478 - val_loss: 0.0045 - val_mse: 0.0041 - val_mae: 0.0454
# Epoch 50/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.0058 - mse: 0.0054 - mae: 0.0512 - val_loss: 0.0046 - val_mse: 0.0042 - val_mae: 0.0480
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0046 - mse: 0.0042 - mae: 0.0480
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0035 - mse: 0.0031 - mae: 0.0415
# Epoch 1/50
# 93/93 [==============================] - 5s 15ms/step - loss: 0.1275 - mse: 0.0264 - mae: 0.0944 - val_loss: 0.0322 - val_mse: 0.0120 - val_mae: 0.0664
# Epoch 2/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0222 - mse: 0.0085 - mae: 0.0582 - val_loss: 0.0099 - val_mse: 0.0065 - val_mae: 0.0497
# Epoch 3/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0088 - mse: 0.0062 - mae: 0.0490 - val_loss: 0.0064 - val_mse: 0.0052 - val_mae: 0.0447
# Epoch 4/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0072 - mse: 0.0062 - mae: 0.0467 - val_loss: 0.0055 - val_mse: 0.0048 - val_mae: 0.0430
# Epoch 5/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0073 - mse: 0.0066 - mae: 0.0467 - val_loss: 0.0057 - val_mse: 0.0051 - val_mae: 0.0449
# Epoch 6/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0055 - mae: 0.0445 - val_loss: 0.0051 - val_mse: 0.0046 - val_mae: 0.0433
# Epoch 7/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0057 - mae: 0.0453 - val_loss: 0.0075 - val_mse: 0.0071 - val_mae: 0.0545
# Epoch 8/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0076 - mse: 0.0071 - mae: 0.0490 - val_loss: 0.0051 - val_mse: 0.0046 - val_mae: 0.0422
# Epoch 9/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0054 - mse: 0.0050 - mae: 0.0425 - val_loss: 0.0053 - val_mse: 0.0049 - val_mae: 0.0466
# Epoch 10/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0059 - mse: 0.0055 - mae: 0.0460 - val_loss: 0.0051 - val_mse: 0.0047 - val_mae: 0.0423
# Epoch 11/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0056 - mae: 0.0450 - val_loss: 0.0044 - val_mse: 0.0041 - val_mae: 0.0390
# Epoch 12/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0050 - mse: 0.0047 - mae: 0.0422 - val_loss: 0.0057 - val_mse: 0.0054 - val_mae: 0.0502
# Epoch 13/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0057 - mae: 0.0450 - val_loss: 0.0044 - val_mse: 0.0040 - val_mae: 0.0393
# Epoch 14/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0049 - mse: 0.0046 - mae: 0.0420 - val_loss: 0.0045 - val_mse: 0.0043 - val_mae: 0.0405
# Epoch 15/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0055 - mse: 0.0052 - mae: 0.0431 - val_loss: 0.0042 - val_mse: 0.0039 - val_mae: 0.0383
# Epoch 16/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0049 - mae: 0.0414 - val_loss: 0.0045 - val_mse: 0.0042 - val_mae: 0.0404
# Epoch 17/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0045 - mae: 0.0412 - val_loss: 0.0042 - val_mse: 0.0040 - val_mae: 0.0382
# Epoch 18/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0050 - mse: 0.0048 - mae: 0.0423 - val_loss: 0.0045 - val_mse: 0.0042 - val_mae: 0.0406
# Epoch 19/50
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0071 - mse: 0.0069 - mae: 0.0430 - val_loss: 0.0046 - val_mse: 0.0043 - val_mae: 0.0401
# Epoch 20/50
# 93/93 [==============================] - 1s 11ms/step - loss: 0.0062 - mse: 0.0059 - mae: 0.0444 - val_loss: 0.0047 - val_mse: 0.0045 - val_mae: 0.0447
# Epoch 21/50
# 93/93 [==============================] - 1s 9ms/step - loss: 0.0054 - mse: 0.0052 - mae: 0.0424 - val_loss: 0.0048 - val_mse: 0.0046 - val_mae: 0.0442
# Epoch 22/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0045 - mse: 0.0043 - mae: 0.0414 - val_loss: 0.0044 - val_mse: 0.0042 - val_mae: 0.0406
# Epoch 23/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0050 - mse: 0.0047 - mae: 0.0409 - val_loss: 0.0047 - val_mse: 0.0045 - val_mae: 0.0417
# Epoch 24/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0040 - mse: 0.0038 - mae: 0.0398 - val_loss: 0.0044 - val_mse: 0.0041 - val_mae: 0.0405
# Epoch 25/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0058 - mse: 0.0056 - mae: 0.0428 - val_loss: 0.0039 - val_mse: 0.0037 - val_mae: 0.0368
# Epoch 26/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0059 - mae: 0.0422 - val_loss: 0.0040 - val_mse: 0.0038 - val_mae: 0.0375
# Epoch 27/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0039 - mse: 0.0037 - mae: 0.0394 - val_loss: 0.0039 - val_mse: 0.0037 - val_mae: 0.0370
# Epoch 28/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0039 - mae: 0.0390 - val_loss: 0.0041 - val_mse: 0.0038 - val_mae: 0.0384
# Epoch 29/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0044 - mse: 0.0041 - mae: 0.0397 - val_loss: 0.0062 - val_mse: 0.0060 - val_mae: 0.0499
# Epoch 30/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0070 - mse: 0.0068 - mae: 0.0467 - val_loss: 0.0040 - val_mse: 0.0037 - val_mae: 0.0370
# Epoch 31/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0046 - mse: 0.0044 - mae: 0.0392 - val_loss: 0.0040 - val_mse: 0.0037 - val_mae: 0.0371
# Epoch 32/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0069 - mse: 0.0066 - mae: 0.0434 - val_loss: 0.0039 - val_mse: 0.0037 - val_mae: 0.0368
# Epoch 33/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0046 - mse: 0.0044 - mae: 0.0396 - val_loss: 0.0041 - val_mse: 0.0039 - val_mae: 0.0393
# Epoch 34/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0045 - mse: 0.0043 - mae: 0.0399 - val_loss: 0.0042 - val_mse: 0.0040 - val_mae: 0.0396
# Epoch 35/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0046 - mae: 0.0402 - val_loss: 0.0041 - val_mse: 0.0039 - val_mae: 0.0385
# Epoch 36/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0049 - mae: 0.0401 - val_loss: 0.0043 - val_mse: 0.0041 - val_mae: 0.0409
# Epoch 37/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0058 - mae: 0.0419 - val_loss: 0.0039 - val_mse: 0.0036 - val_mae: 0.0370
# Epoch 38/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0055 - mse: 0.0053 - mae: 0.0392 - val_loss: 0.0040 - val_mse: 0.0037 - val_mae: 0.0376
# Epoch 39/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0044 - mse: 0.0042 - mae: 0.0397 - val_loss: 0.0042 - val_mse: 0.0040 - val_mae: 0.0404
# Epoch 40/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0060 - mae: 0.0434 - val_loss: 0.0046 - val_mse: 0.0044 - val_mae: 0.0437
# Epoch 41/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0053 - mse: 0.0050 - mae: 0.0418 - val_loss: 0.0038 - val_mse: 0.0036 - val_mae: 0.0367
# Epoch 42/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0045 - mae: 0.0397 - val_loss: 0.0039 - val_mse: 0.0037 - val_mae: 0.0381
# Epoch 43/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0046 - mae: 0.0386 - val_loss: 0.0039 - val_mse: 0.0037 - val_mae: 0.0376
# Epoch 44/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0045 - mae: 0.0386 - val_loss: 0.0040 - val_mse: 0.0037 - val_mae: 0.0381
# Epoch 45/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0042 - mse: 0.0040 - mae: 0.0379 - val_loss: 0.0040 - val_mse: 0.0038 - val_mae: 0.0388
# Epoch 46/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0046 - mse: 0.0044 - mae: 0.0402 - val_loss: 0.0038 - val_mse: 0.0036 - val_mae: 0.0376
# Epoch 47/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0050 - mse: 0.0048 - mae: 0.0401 - val_loss: 0.0042 - val_mse: 0.0040 - val_mae: 0.0396
# Epoch 48/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0056 - mse: 0.0053 - mae: 0.0413 - val_loss: 0.0044 - val_mse: 0.0042 - val_mae: 0.0424
# Epoch 49/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0045 - mae: 0.0400 - val_loss: 0.0039 - val_mse: 0.0037 - val_mae: 0.0388
# Epoch 50/50
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0032 - mse: 0.0030 - mae: 0.0368 - val_loss: 0.0041 - val_mse: 0.0039 - val_mae: 0.0401
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0041 - mse: 0.0039 - mae: 0.0401
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0036 - mse: 0.0034 - mae: 0.0421

# %%
# print(train_mse)
# 以保留四位小数打印
print(np.round(train_mse, 5))
print(np.round(np.mean(train_mse),5))
# Out:
# [0.00129 0.00115 0.00325 0.00419 0.0039 ]
# 0.00275

# %%
# print(test_mes)
# 以保留四位小数打印
print(np.round(test_mes, 5))
print(np.round(np.mean(test_mes),5))
# Out:
# [0.00319 0.00338 0.00299 0.00314 0.00336]
# 0.00321
