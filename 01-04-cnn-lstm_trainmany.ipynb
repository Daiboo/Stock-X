# %% [markdown]
# # Stock Market Prediction using CNN-LSTM model
# This project is about analysis of Stock Market and providing predictions to the stockholders.
#
# For this, we used CNN-LSTM approach to create a blank model, then use it to train on stock market data. Further implementation is discussed below...

# %% [markdown]
# # Data collect

# %% [markdown]
# Before preprocessing data, a function to fetch real-time stock data (using Alpha Vantage API) is made

# %%
key = "TV1WC9ANR799K1H1"

import requests
import csv
from tqdm import tqdm
import pandas as pd
def request_stock_price_list(symbol, size, token):
    q_string = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={}&outputsize={}&apikey={}'
    proxies = {
        "http": "http://127.0.0.1:7890",
        "https": "http://127.0.0.1:7890",
    }
    print("Retrieving stock price data from Alpha Vantage (This may take a while)...")
    r = requests.get(q_string.format(symbol, size, token), proxies=proxies)
    print("Data has been successfully downloaded...")
    date = []
    colnames = list(range(0, 5))
    df = pd.DataFrame(columns = colnames)
    print("Sorting the retrieved data into a dataframe...")
    for i in tqdm(r.json()['Time Series (Daily)'].keys()):
        date.append(i)
        row = pd.DataFrame.from_dict(r.json()['Time Series (Daily)'][i], orient='index').reset_index().T[1:]
        df = pd.concat([df, row], ignore_index=True)
    df.columns = ["Open", "High", "Low", "Close", "Volume"]
    df['Date'] = date
    return df

# %%
# cv1 = request_stock_price_list('600104.SHH', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHH.csv')

# %%
# cv1 = request_stock_price_list('000002.SHZ', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHZ.csv')

# %%
# cv1 = request_stock_price_list('TSCO.LON', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_LON.csv')

# %%
# cv1 = request_stock_price_list('SHOP.TRT', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_TRT.csv')

# %%
# cv1 = request_stock_price_list('RELIANCE.BSE', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_BSE.csv')

# %%
# UNCOMMENT THE CELL IF DATA IS NEEDED TO BE LOADED FOR 1ST TIME

# cv1 = request_stock_price_list('IBM', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data.csv')

# %% [markdown]
# # Training part

# %% [markdown]
# This part has 2 subparts: CNN and LSTM
#
# For CNN, the layers are created with sizes 64,128,64 with kernel size = 3. In every layer, TimeDistributed function is added to track the features for every temporal slice of data with respect to time. In between, MaxPooling layers are added.
#
# After that, it's passed to Bi-LSTM layers

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")


# 封装
class StockPredictor:
    def __init__(self,data_path,window_size=100):
        self.data_path = data_path      # 数据路径
        
        self.window_size = window_size    # 窗口大小
        self.train_X,self.test_X,self.train_Y,self.test_Y = self.__pressing_data(self.data_path)  # 第一步：数据预处理
        self.model = self.__construct_model()                                            # 第二步：模型
        self.history = None                                                       
        
    
    def __pressing_data(self,data_path,shuffle=True):
        window_size = self.window_size
        data = pd.read_csv(data_path, usecols=["Close"])
        data.reset_index(drop=True, inplace=True)
        data.fillna(data.mean(), inplace=True)

        close_column = data['Close']
        X = []
        Y = []
        for i in range(1 , len(close_column) - window_size -1 , 1):
            first = close_column[i]
            temp = []
            temp2 = []
            for j in range(window_size):
                temp.append((close_column[i + j] - first) / first)
            temp2.append((close_column[i + window_size] - first) / first)
            X.append(np.array(temp).reshape(100, 1))
            Y.append(np.array(temp2).reshape(1, 1))

        x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=shuffle)

        train_X = np.array(x_train)
        test_X = np.array(x_test)
        train_Y = np.array(y_train)
        test_Y = np.array(y_test)
        train_X = train_X.reshape(train_X.shape[0],1,100,1)
        test_X = test_X.reshape(test_X.shape[0],1,100,1)
        return train_X, test_X, train_Y, test_Y

    
    def __construct_model(self, dropout=0.5):
        window_size = self.window_size
        model = tf.keras.Sequential()
        # Creating the Neural Network model here...
        # CNN layers
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, window_size, 1))))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Flatten()))
        # model.add(Dense(5, kernel_regularizer=L2(0.01)))
        # LSTM layers
        model.add(Bidirectional(LSTM(100, return_sequences=True)))
        model.add(Dropout(dropout))
        model.add(Bidirectional(LSTM(100, return_sequences=False)))
        model.add(Dropout(dropout))
        #Final layers
        model.add(Dense(1, activation='linear'))
        model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
        return model

    def fit(self, epochs=40, batch_size=40, verbose=1, shuffle=True):
        # 训练模型
        self.history = self.model.fit(self.train_X, self.train_Y, epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=shuffle, validation_data=(self.test_X, self.test_Y))
        
    
    def plot(self):
        # 绘制训练过程
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mse'], label='train mse')
        plt.plot(self.history.history['val_mse'], label='val mse')
        plt.xlabel("epoch")
        plt.ylabel("MSE")
        plt.legend()
        plt.show()
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mae'], label='train mae')
        plt.plot(self.history.history['val_mae'], label='val mae')
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.show()
        
    def summary(self):
        self.model.summary()
    
    def evaluate(self):
        return self.model.evaluate(self.test_X, self.test_Y)

    def __predict_handle(self,data_path,train_X,test_X,test_Y):
        predicted_pre  = self.model.predict(test_X)   # 预测
        test_label_pre = test_Y.reshape(-1,1)       # 真实值
        predicted_pre = np.array(predicted_pre[:,0]).reshape(-1,1)
        
        close_column = pd.read_csv(data_path, usecols=["Close"])
        close_column.reset_index(drop=True, inplace=True)
        close_column.fillna(close_column.mean(), inplace=True)
        close_column = close_column['Close']
        
        test_label_raw = np.zeros(len(test_label_pre))
        predicted_raw = np.zeros(len(predicted_pre))
        len_t = len(train_X)
        for j in range(len_t , len_t + len(test_X)):
            temp = close_column[j]
            test_label_raw[j - len_t] = test_label_pre[j - len_t] * temp + temp
            predicted_raw[j - len_t] = predicted_pre[j - len_t] * temp + temp

        plt.figure(figsize=(15, 6))
        plt.plot(predicted_raw, color = 'green', label = 'Predicted  Stock Price')
        plt.plot(test_label_raw, color = 'red', label = 'Real Stock Price')
        plt.title(' Stock Price Prediction')
        plt.xlabel('Time')
        plt.ylabel(' Stock Price')
        plt.legend()
        plt.show()

    def predict(self):
        self.__predict_handle(self.data_path,self.train_X,self.test_X,self.test_Y)

    
    def predict_others(self, data_paths):
        train_X, test_X, train_Y, test_Y = self.__pressing_data(data_paths,shuffle=False)
        self.__predict_handle(data_paths,train_X,test_X,test_Y)
        return self.model.evaluate(test_X, test_Y)
        


    def save(self, path):
        self.model.save(path)

    def load(self, path):
        self.model = tf.keras.models.load_model(path)

# %%
data_paths = ["data/NASDAQ/abe.us.txt","data/data_LON.csv", "data/data_SHH.csv", "data/data_SHZ.csv","data/data_BSE.csv"] 
train_mse = []
test_mes = []
for data_path in data_paths:
    stock = StockPredictor(data_path)
    stock.fit()
    train_mse.append(stock.evaluate()[1])
    test_mes.append(stock.predict_others('./data/data.csv')[1])
    stock.save('model/' + data_path.split('.')[0].split('/')[1] + '.h5')
# Out:
# Epoch 1/40
# 62/62 [==============================] - 5s 25ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0827 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0442
# Epoch 2/40
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0477 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0424
# Epoch 3/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0438 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0362
# Epoch 4/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0376 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0343
# Epoch 5/40
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0374 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0330
# Epoch 6/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0369 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0379
# Epoch 7/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0364 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0338
# Epoch 8/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0335 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0308
# Epoch 9/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0341 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0317
# Epoch 10/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0323 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0300
# Epoch 11/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0329 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0327
# Epoch 12/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0345 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0319
# Epoch 13/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0314 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0295
# Epoch 14/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0321 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0312
# Epoch 15/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0321 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0318
# Epoch 16/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0318 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0303
# Epoch 17/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0311 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0300
# Epoch 18/40
# 62/62 [==============================] - 1s 15ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0313 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0288
# Epoch 19/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0313 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0293
# Epoch 20/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0290 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0328
# Epoch 21/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0329 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0296
# Epoch 22/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0320 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0299
# Epoch 23/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0325 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0281
# Epoch 24/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0317 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0300
# Epoch 25/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0288 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0275
# Epoch 26/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0302 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0282
# Epoch 27/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0283
# Epoch 28/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0284 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0278
# Epoch 29/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0283 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0283
# Epoch 30/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0280 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0277
# Epoch 31/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0288 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0268
# Epoch 32/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0279 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0274
# Epoch 33/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0293 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0271
# Epoch 34/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0273 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0261
# Epoch 35/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0268 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0261
# Epoch 36/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0260 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0271
# Epoch 37/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0269 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0261
# Epoch 38/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0257 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0270
# Epoch 39/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0260 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0260
# Epoch 40/40
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0264 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0260
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0260
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0596
# Epoch 1/40
# 94/94 [==============================] - 5s 21ms/step - loss: 0.0094 - mse: 0.0094 - mae: 0.0713 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0463
# Epoch 2/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0436 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0393
# Epoch 3/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0381 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0318
# Epoch 4/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0373 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0371
# Epoch 5/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0349 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0318
# Epoch 6/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0358 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0342
# Epoch 7/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0338 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0317
# Epoch 8/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0355 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0308
# Epoch 9/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0340 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0329
# Epoch 10/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0342 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0338
# Epoch 11/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0341 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0316
# Epoch 12/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0336 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0292
# Epoch 13/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0318 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0345
# Epoch 14/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0330 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0314
# Epoch 15/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0327 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0296
# Epoch 16/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0307 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0339
# Epoch 17/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0322 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0326
# Epoch 18/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0320 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0291
# Epoch 19/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0309 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0295
# Epoch 20/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0312 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0283
# Epoch 21/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0304 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0288
# Epoch 22/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0301 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0291
# Epoch 23/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0297 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0296
# Epoch 24/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0281 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0319
# Epoch 25/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0309 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0292
# Epoch 26/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0298 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0304
# Epoch 27/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0287 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0298
# Epoch 28/40
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0284
# Epoch 29/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0282
# Epoch 30/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0291 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0324
# Epoch 31/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0298
# Epoch 32/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0278 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0294
# Epoch 33/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0280 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0288
# Epoch 34/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0277 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0302
# Epoch 35/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0279 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0279
# Epoch 36/40
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0271 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0341
# Epoch 37/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0281 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0301
# Epoch 38/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0267 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0293
# Epoch 39/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0268 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0284
# Epoch 40/40
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0269 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0289
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0289
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0526
# Epoch 1/40
# 86/86 [==============================] - 5s 22ms/step - loss: 0.0347 - mse: 0.0347 - mae: 0.1253 - val_loss: 0.0126 - val_mse: 0.0126 - val_mae: 0.0727
# Epoch 2/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0123 - mse: 0.0123 - mae: 0.0740 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0596
# Epoch 3/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0108 - mse: 0.0108 - mae: 0.0690 - val_loss: 0.0111 - val_mse: 0.0111 - val_mae: 0.0686
# Epoch 4/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0106 - mse: 0.0106 - mae: 0.0677 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0566
# Epoch 5/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0639 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0569
# Epoch 6/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0597 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0519
# Epoch 7/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0585 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0514
# Epoch 8/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0602 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0496
# Epoch 9/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0547 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0488
# Epoch 10/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0553 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0510
# Epoch 11/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0560 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0509
# Epoch 12/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0553 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0465
# Epoch 13/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0545 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0482
# Epoch 14/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0558 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0465
# Epoch 15/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0547 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0572
# Epoch 16/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0562 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0510
# Epoch 17/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0517 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0486
# Epoch 18/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0514 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0485
# Epoch 19/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0514 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0458
# Epoch 20/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0497 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0463
# Epoch 21/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0481 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0487
# Epoch 22/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0489 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0476
# Epoch 23/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0491 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0449
# Epoch 24/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0492 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0499
# Epoch 25/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0537 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0595
# Epoch 26/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0506 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0452
# Epoch 27/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0463 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0441
# Epoch 28/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0477 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0454
# Epoch 29/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0463 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0465
# Epoch 30/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0455 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0428
# Epoch 31/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0440 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0490
# Epoch 32/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0461 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0488
# Epoch 33/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0452 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0420
# Epoch 34/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0447 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0484
# Epoch 35/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0442 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0509
# Epoch 36/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0458 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0470
# Epoch 37/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0436 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0419
# Epoch 38/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0443 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0465
# Epoch 39/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0439 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0436
# Epoch 40/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0436 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0420
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0420
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0509
# Epoch 1/40
# 86/86 [==============================] - 6s 24ms/step - loss: 0.0860 - mse: 0.0860 - mae: 0.1531 - val_loss: 0.0303 - val_mse: 0.0303 - val_mae: 0.0936
# Epoch 2/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0186 - mse: 0.0186 - mae: 0.0881 - val_loss: 0.0283 - val_mse: 0.0283 - val_mae: 0.0966
# Epoch 3/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0203 - mse: 0.0203 - mae: 0.0903 - val_loss: 0.0210 - val_mse: 0.0210 - val_mae: 0.0852
# Epoch 4/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0135 - mse: 0.0135 - mae: 0.0752 - val_loss: 0.0159 - val_mse: 0.0159 - val_mae: 0.0739
# Epoch 5/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0702 - val_loss: 0.0186 - val_mse: 0.0186 - val_mae: 0.0838
# Epoch 6/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0135 - mse: 0.0135 - mae: 0.0738 - val_loss: 0.0207 - val_mse: 0.0207 - val_mae: 0.0838
# Epoch 7/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0733 - val_loss: 0.0161 - val_mse: 0.0161 - val_mae: 0.0737
# Epoch 8/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0113 - mse: 0.0113 - mae: 0.0694 - val_loss: 0.0143 - val_mse: 0.0143 - val_mae: 0.0739
# Epoch 9/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0111 - mse: 0.0111 - mae: 0.0701 - val_loss: 0.0145 - val_mse: 0.0145 - val_mae: 0.0739
# Epoch 10/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0116 - mse: 0.0116 - mae: 0.0671 - val_loss: 0.0145 - val_mse: 0.0145 - val_mae: 0.0740
# Epoch 11/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0124 - mse: 0.0124 - mae: 0.0734 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0693
# Epoch 12/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0107 - mse: 0.0107 - mae: 0.0668 - val_loss: 0.0134 - val_mse: 0.0134 - val_mae: 0.0686
# Epoch 13/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0140 - mse: 0.0140 - mae: 0.0722 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0646
# Epoch 14/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0670 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0699
# Epoch 15/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0647 - val_loss: 0.0125 - val_mse: 0.0125 - val_mae: 0.0680
# Epoch 16/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0103 - mse: 0.0103 - mae: 0.0654 - val_loss: 0.0114 - val_mse: 0.0114 - val_mae: 0.0692
# Epoch 17/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0659 - val_loss: 0.0140 - val_mse: 0.0140 - val_mae: 0.0692
# Epoch 18/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0645 - val_loss: 0.0131 - val_mse: 0.0131 - val_mae: 0.0731
# Epoch 19/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0630 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0665
# Epoch 20/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0631 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0687
# Epoch 21/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0645 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0630
# Epoch 22/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0628 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0599
# Epoch 23/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0578 - val_loss: 0.0134 - val_mse: 0.0134 - val_mae: 0.0683
# Epoch 24/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0610 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0610
# Epoch 25/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0584 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0595
# Epoch 26/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0601 - val_loss: 0.0114 - val_mse: 0.0114 - val_mae: 0.0630
# Epoch 27/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0580 - val_loss: 0.0087 - val_mse: 0.0087 - val_mae: 0.0614
# Epoch 28/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0612 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0603
# Epoch 29/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0616 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0661
# Epoch 30/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0609 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0594
# Epoch 31/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0564 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0616
# Epoch 32/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0572 - val_loss: 0.0133 - val_mse: 0.0133 - val_mae: 0.0685
# Epoch 33/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0576 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0559
# Epoch 34/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0559 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0646
# Epoch 35/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0568 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0563
# Epoch 36/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0535 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0590
# Epoch 37/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0543 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0592
# Epoch 38/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0555 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0555
# Epoch 39/40
# 86/86 [==============================] - 1s 16ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0531 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0553
# Epoch 40/40
# 86/86 [==============================] - 1s 15ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0541 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0558
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0558
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0510
# Epoch 1/40
# 92/92 [==============================] - 5s 23ms/step - loss: 0.0281 - mse: 0.0281 - mae: 0.1055 - val_loss: 0.0124 - val_mse: 0.0124 - val_mae: 0.0694
# Epoch 2/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0106 - mse: 0.0106 - mae: 0.0637 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0524
# Epoch 3/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0562 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0563
# Epoch 4/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0541 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0472
# Epoch 5/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0524 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0568
# Epoch 6/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0521 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0484
# Epoch 7/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0521 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0454
# Epoch 8/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0507 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0467
# Epoch 9/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0494 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0445
# Epoch 10/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0484 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0443
# Epoch 11/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0472 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0457
# Epoch 12/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0479 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0465
# Epoch 13/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0478 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0471
# Epoch 14/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0475 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0481
# Epoch 15/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0465 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0435
# Epoch 16/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0463 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0461
# Epoch 17/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0506 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0425
# Epoch 18/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0466 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0438
# Epoch 19/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0451 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0529
# Epoch 20/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0486 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0527
# Epoch 21/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0475 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0434
# Epoch 22/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0445 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0444
# Epoch 23/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0446 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0466
# Epoch 24/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0464 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0510
# Epoch 25/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0441 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0494
# Epoch 26/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0483 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0426
# Epoch 27/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0446 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0436
# Epoch 28/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0446 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0474
# Epoch 29/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0445 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0455
# Epoch 30/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0448 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0425
# Epoch 31/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0470 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0436
# Epoch 32/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0440 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0437
# Epoch 33/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0443 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0440
# Epoch 34/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0433 - val_loss: 0.0044 - val_mse: 0.0044 - val_mae: 0.0443
# Epoch 35/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0445 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0434
# Epoch 36/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0422 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0456
# Epoch 37/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0440 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0439
# Epoch 38/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0417 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0486
# Epoch 39/40
# 92/92 [==============================] - 1s 16ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0420 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0425
# Epoch 40/40
# 92/92 [==============================] - 1s 15ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0434 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0437
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0437
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0549

# %%
# print(train_mse)
# 以保留四位小数打印
print(np.round(train_mse, 5))
print(np.round(np.mean(train_mse),5))
# Out:
# [0.00118 0.00167 0.00328 0.00711 0.00413]
# 0.00347

# %%
# print(test_mes)
# 以保留四位小数打印
print(np.round(test_mes, 5))
print(np.round(np.mean(test_mes),5))
# Out:
# [0.00646 0.00497 0.00477 0.00515 0.00533]
# 0.00534
