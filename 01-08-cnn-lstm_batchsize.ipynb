# %% [markdown]
# # Stock Market Prediction using CNN-LSTM model
# This project is about analysis of Stock Market and providing predictions to the stockholders.
#
# For this, we used CNN-LSTM approach to create a blank model, then use it to train on stock market data. Further implementation is discussed below...

# %% [markdown]
# # Data collect

# %% [markdown]
# Before preprocessing data, a function to fetch real-time stock data (using Alpha Vantage API) is made

# %%
key = "TV1WC9ANR799K1H1"

import requests
import csv
from tqdm import tqdm
import pandas as pd
def request_stock_price_list(symbol, size, token):
    q_string = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={}&outputsize={}&apikey={}'
    proxies = {
        "http": "http://127.0.0.1:7890",
        "https": "http://127.0.0.1:7890",
    }
    print("Retrieving stock price data from Alpha Vantage (This may take a while)...")
    r = requests.get(q_string.format(symbol, size, token), proxies=proxies)
    print("Data has been successfully downloaded...")
    date = []
    colnames = list(range(0, 5))
    df = pd.DataFrame(columns = colnames)
    print("Sorting the retrieved data into a dataframe...")
    for i in tqdm(r.json()['Time Series (Daily)'].keys()):
        date.append(i)
        row = pd.DataFrame.from_dict(r.json()['Time Series (Daily)'][i], orient='index').reset_index().T[1:]
        df = pd.concat([df, row], ignore_index=True)
    df.columns = ["Open", "High", "Low", "Close", "Volume"]
    df['Date'] = date
    return df

# %%
# cv1 = request_stock_price_list('600104.SHH', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHH.csv')

# %%
# cv1 = request_stock_price_list('000002.SHZ', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_SHZ.csv')

# %%
# cv1 = request_stock_price_list('TSCO.LON', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_LON.csv')

# %%
# cv1 = request_stock_price_list('SHOP.TRT', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_TRT.csv')

# %%
# cv1 = request_stock_price_list('RELIANCE.BSE', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data_BSE.csv')

# %%
# UNCOMMENT THE CELL IF DATA IS NEEDED TO BE LOADED FOR 1ST TIME

# cv1 = request_stock_price_list('IBM', 'full', key)
# print(cv1.head)
# cv1.to_csv('./data/data.csv')

# %% [markdown]
# # Training part

# %% [markdown]
# This part has 2 subparts: CNN and LSTM
#
# For CNN, the layers are created with sizes 64,128,64 with kernel size = 3. In every layer, TimeDistributed function is added to track the features for every temporal slice of data with respect to time. In between, MaxPooling layers are added.
#
# After that, it's passed to Bi-LSTM layers

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import datetime as dt
from datetime import datetime    
sns.set_style("whitegrid")
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")


# 封装
class StockPredictor:
    def __init__(self,data_path,window_size=100):
        self.data_path = data_path      # 数据路径
        
        self.window_size = window_size    # 窗口大小
        self.train_X,self.test_X,self.train_Y,self.test_Y = self.__pressing_data(self.data_path)  # 第一步：数据预处理
        self.model = self.__construct_model()                                            # 第二步：模型
        self.history = None                                                       
        
    
    def __pressing_data(self,data_path,shuffle=True):
        window_size = self.window_size
        data = pd.read_csv(data_path, usecols=["Close"])
        data.reset_index(drop=True, inplace=True)
        data.fillna(data.mean(), inplace=True)

        close_column = data['Close']
        X = []
        Y = []
        for i in range(1 , len(close_column) - window_size -1 , 1):
            first = close_column[i]
            temp = []
            temp2 = []
            for j in range(window_size):
                temp.append((close_column[i + j] - first) / first)
            temp2.append((close_column[i + window_size] - first) / first)
            X.append(np.array(temp).reshape(window_size, 1))
            Y.append(np.array(temp2).reshape(1, 1))

        x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=shuffle)

        train_X = np.array(x_train)
        test_X = np.array(x_test)
        train_Y = np.array(y_train)
        test_Y = np.array(y_test)
        train_X = train_X.reshape(train_X.shape[0],1,window_size,1)
        test_X = test_X.reshape(test_X.shape[0],1,window_size,1)
        return train_X, test_X, train_Y, test_Y

    
    def __construct_model(self, dropout=0.5):
        window_size = self.window_size
        model = tf.keras.Sequential()
        # Creating the Neural Network model here...
        # CNN layers
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, window_size, 1))))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
        model.add(TimeDistributed(MaxPooling1D(2)))
        model.add(TimeDistributed(Flatten()))
        # model.add(Dense(5, kernel_regularizer=L2(0.01)))
        # LSTM layers
        model.add(Bidirectional(LSTM(100, return_sequences=True)))
        model.add(Dropout(dropout))
        model.add(Bidirectional(LSTM(100, return_sequences=False)))
        model.add(Dropout(dropout))
        #Final layers
        model.add(Dense(1, activation='linear'))
        model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
        return model

    def fit(self, epochs=40, batch_size=40, verbose=1, shuffle=True):
        # 训练模型
        self.history = self.model.fit(self.train_X, self.train_Y, epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=shuffle, validation_data=(self.test_X, self.test_Y))
        
    
    def plot(self):
        # 绘制训练过程
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mse'], label='train mse')
        plt.plot(self.history.history['val_mse'], label='val mse')
        plt.xlabel("epoch")
        plt.ylabel("MSE")
        plt.legend()
        plt.show()
        plt.figure(figsize=(10, 6))
        plt.plot(self.history.history['mae'], label='train mae')
        plt.plot(self.history.history['val_mae'], label='val mae')
        plt.xlabel("epoch")
        plt.ylabel("MAE")
        plt.legend()
        plt.show()
        
    def summary(self):
        self.model.summary()
    
    def evaluate(self):
        return self.model.evaluate(self.test_X, self.test_Y)

    def __predict_handle(self,data_path,train_X,test_X,test_Y):
        predicted_pre  = self.model.predict(test_X)   # 预测
        test_label_pre = test_Y.reshape(-1,1)       # 真实值
        predicted_pre = np.array(predicted_pre[:,0]).reshape(-1,1)
        
        close_column = pd.read_csv(data_path, usecols=["Close"])
        close_column.reset_index(drop=True, inplace=True)
        close_column.fillna(close_column.mean(), inplace=True)
        close_column = close_column['Close']
        
        test_label_raw = np.zeros(len(test_label_pre))
        predicted_raw = np.zeros(len(predicted_pre))
        len_t = len(train_X)
        for j in range(len_t , len_t + len(test_X)):
            temp = close_column[j]
            test_label_raw[j - len_t] = test_label_pre[j - len_t] * temp + temp
            predicted_raw[j - len_t] = predicted_pre[j - len_t] * temp + temp

        plt.figure(figsize=(15, 6))
        plt.plot(predicted_raw, color = 'green', label = 'Predicted  Stock Price')
        plt.plot(test_label_raw, color = 'red', label = 'Real Stock Price')
        plt.title(' Stock Price Prediction')
        plt.xlabel('Time')
        plt.ylabel(' Stock Price')
        plt.legend()
        plt.show()

    def predict(self):
        self.__predict_handle(self.data_path,self.train_X,self.test_X,self.test_Y)

    
    def predict_others(self, data_paths):
        train_X, test_X, train_Y, test_Y = self.__pressing_data(data_paths,shuffle=False)
        self.__predict_handle(data_paths,train_X,test_X,test_Y)
        return self.model.evaluate(test_X, test_Y)
        


    def save(self, path):
        self.model.save(path)

    def load(self, path):
        self.model = tf.keras.models.load_model(path)

# %% [markdown]
# # 训练部分

# %%
data_paths = ["data/NASDAQ/abe.us.txt","data/data_LON.csv", "data/data_SHH.csv", "data/data_SHZ.csv","data/data_BSE.csv"] 
train_mse = []
test_mes = []
for data_path in data_paths:
    stock = StockPredictor(data_path,window_size=50)
    stock.fit(batch_size=40)
    train_mse.append(stock.evaluate()[1])
    test_mes.append(stock.predict_others('./data/data.csv')[1])
    stock.save('model/' + data_path.split('.')[0].split('/')[1] + '.h5')
# Out:
# Epoch 1/40
# 63/63 [==============================] - 5s 18ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0588 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0359
# Epoch 2/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0361 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0304
# Epoch 3/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0328 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0277
# Epoch 4/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0318 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0304
# Epoch 5/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0318 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0257
# Epoch 6/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0288 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0251
# Epoch 7/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0289 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0249
# Epoch 8/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0297 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0241
# Epoch 9/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0297 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0247
# Epoch 10/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0284 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0241
# Epoch 11/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0296 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0237
# Epoch 12/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0286 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0235
# Epoch 13/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0293 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0241
# Epoch 14/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0275 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0278
# Epoch 15/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0303 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0288
# Epoch 16/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0283 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0271
# Epoch 17/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0295 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0236
# Epoch 18/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0268 - val_loss: 9.9828e-04 - val_mse: 9.9828e-04 - val_mae: 0.0233
# Epoch 19/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0273 - val_loss: 9.6219e-04 - val_mse: 9.6219e-04 - val_mae: 0.0230
# Epoch 20/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0268 - val_loss: 9.9857e-04 - val_mse: 9.9857e-04 - val_mae: 0.0233
# Epoch 21/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0257 - val_loss: 9.7787e-04 - val_mse: 9.7787e-04 - val_mae: 0.0233
# Epoch 22/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0271 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0259
# Epoch 23/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0277 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0234
# Epoch 24/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0263 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0244
# Epoch 25/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0262 - val_loss: 9.2274e-04 - val_mse: 9.2274e-04 - val_mae: 0.0227
# Epoch 26/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0258
# Epoch 27/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0275 - val_loss: 9.2383e-04 - val_mse: 9.2383e-04 - val_mae: 0.0225
# Epoch 28/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0248 - val_loss: 9.8356e-04 - val_mse: 9.8356e-04 - val_mae: 0.0237
# Epoch 29/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0256 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0240
# Epoch 30/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0258 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0309
# Epoch 31/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0270 - val_loss: 8.9408e-04 - val_mse: 8.9408e-04 - val_mae: 0.0222
# Epoch 32/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0253 - val_loss: 9.8324e-04 - val_mse: 9.8324e-04 - val_mae: 0.0237
# Epoch 33/40
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0253 - val_loss: 9.7221e-04 - val_mse: 9.7221e-04 - val_mae: 0.0235
# Epoch 34/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0250 - val_loss: 9.3316e-04 - val_mse: 9.3316e-04 - val_mae: 0.0226
# Epoch 35/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0250 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0252
# Epoch 36/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0246 - val_loss: 9.6145e-04 - val_mse: 9.6145e-04 - val_mae: 0.0231
# Epoch 37/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0242 - val_loss: 9.9967e-04 - val_mse: 9.9967e-04 - val_mae: 0.0240
# Epoch 38/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0248 - val_loss: 9.1728e-04 - val_mse: 9.1728e-04 - val_mae: 0.0223
# Epoch 39/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0254 - val_loss: 8.7074e-04 - val_mse: 8.7074e-04 - val_mae: 0.0223
# Epoch 40/40
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0246 - val_loss: 9.5322e-04 - val_mse: 9.5322e-04 - val_mae: 0.0229
# 20/20 [==============================] - 0s 2ms/step - loss: 9.5322e-04 - mse: 9.5322e-04 - mae: 0.0229
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0451
# Epoch 1/40
# 95/95 [==============================] - 5s 15ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0572 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0313
# Epoch 2/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0353 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0292
# Epoch 3/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0301 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0285
# Epoch 4/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0298 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0280
# Epoch 5/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0290 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0287
# Epoch 6/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0292 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0269
# Epoch 7/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0295 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0281
# Epoch 8/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0284 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0268
# Epoch 9/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0288 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0289
# Epoch 10/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0307 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0301
# Epoch 11/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0278 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0269
# Epoch 12/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0278 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0262
# Epoch 13/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0276 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0267
# Epoch 14/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0272 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0271
# Epoch 15/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0275 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0265
# Epoch 16/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0275 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0253
# Epoch 17/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0278 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0261
# Epoch 18/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0269 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0277
# Epoch 19/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0271 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0257
# Epoch 20/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0265 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0266
# Epoch 21/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0264 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0255
# Epoch 22/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0259 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0274
# Epoch 23/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0266 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0285
# Epoch 24/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0269 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0250
# Epoch 25/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0253 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0254
# Epoch 26/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0251 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0263
# Epoch 27/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0251 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0265
# Epoch 28/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0252 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0264
# Epoch 29/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0258 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0282
# Epoch 30/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0256 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0266
# Epoch 31/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0247 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0251
# Epoch 32/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0251 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0249
# Epoch 33/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0260
# Epoch 34/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0245 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0241
# Epoch 35/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0247 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0252
# Epoch 36/40
# 95/95 [==============================] - 1s 7ms/step - loss: 9.6869e-04 - mse: 9.6869e-04 - mae: 0.0237 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0250
# Epoch 37/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0248 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0279
# Epoch 38/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0269
# Epoch 39/40
# 95/95 [==============================] - 1s 7ms/step - loss: 9.4171e-04 - mse: 9.4171e-04 - mae: 0.0231 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0255
# Epoch 40/40
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0239 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0254
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0254
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0424
# Epoch 1/40
# 87/87 [==============================] - 4s 16ms/step - loss: 0.0168 - mse: 0.0168 - mae: 0.0919 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0571
# Epoch 2/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0543 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0566
# Epoch 3/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0524 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0482
# Epoch 4/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0484 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0553
# Epoch 5/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0495 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0448
# Epoch 6/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0458 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0465
# Epoch 7/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0491 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0441
# Epoch 8/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0470 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0453
# Epoch 9/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0460 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0443
# Epoch 10/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0452 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0470
# Epoch 11/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0458 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0473
# Epoch 12/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0467 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0451
# Epoch 13/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0463 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0440
# Epoch 14/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0427 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0466
# Epoch 15/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0446 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0455
# Epoch 16/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0450 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0454
# Epoch 17/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0434 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0486
# Epoch 18/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0440 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0442
# Epoch 19/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0424 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0437
# Epoch 20/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0410 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0427
# Epoch 21/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0430 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0444
# Epoch 22/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0418 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0428
# Epoch 23/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0419 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0449
# Epoch 24/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mse: 0.0039 - val_mae: 0.0449
# Epoch 25/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0409 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0440
# Epoch 26/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0393 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0439
# Epoch 27/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0398 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0429
# Epoch 28/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0381 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0439
# Epoch 29/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0389 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0445
# Epoch 30/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0399 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0445
# Epoch 31/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0389 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0417
# Epoch 32/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0383 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0419
# Epoch 33/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0377 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0421
# Epoch 34/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0395 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0413
# Epoch 35/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0371 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0415
# Epoch 36/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0378 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0433
# Epoch 37/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0373 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0413
# Epoch 38/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0366 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0463
# Epoch 39/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0372 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0430
# Epoch 40/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0370 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0404
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0404
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0398
# Epoch 1/40
# 87/87 [==============================] - 5s 16ms/step - loss: 0.0235 - mse: 0.0235 - mae: 0.0947 - val_loss: 0.0210 - val_mse: 0.0210 - val_mae: 0.0785
# Epoch 2/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0097 - mse: 0.0097 - mae: 0.0665 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0595
# Epoch 3/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0092 - mse: 0.0092 - mae: 0.0620 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0532
# Epoch 4/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0578 - val_loss: 0.0108 - val_mse: 0.0108 - val_mae: 0.0565
# Epoch 5/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0065 - mse: 0.0065 - mae: 0.0554 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0515
# Epoch 6/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0558 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0507
# Epoch 7/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0519 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0511
# Epoch 8/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0553 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0526
# Epoch 9/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0557 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0495
# Epoch 10/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0506 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0539
# Epoch 11/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0519 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0499
# Epoch 12/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0492 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0487
# Epoch 13/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0508 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0509
# Epoch 14/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0522 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0490
# Epoch 15/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0516 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0501
# Epoch 16/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0496 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0502
# Epoch 17/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0484 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0474
# Epoch 18/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0478 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0508
# Epoch 19/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0511 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0500
# Epoch 20/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0484 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0489
# Epoch 21/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0481 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0512
# Epoch 22/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0493 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0469
# Epoch 23/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0458 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0490
# Epoch 24/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0488 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0460
# Epoch 25/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0453 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0551
# Epoch 26/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0478 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0455
# Epoch 27/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0454 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0473
# Epoch 28/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0451 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0509
# Epoch 29/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0449 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0499
# Epoch 30/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0479 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0460
# Epoch 31/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0441 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0524
# Epoch 32/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0464 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0473
# Epoch 33/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0446 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0484
# Epoch 34/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0426 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0479
# Epoch 35/40
# 87/87 [==============================] - 1s 8ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0436 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0462
# Epoch 36/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0449 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0499
# Epoch 37/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0456 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0476
# Epoch 38/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0428 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0470
# Epoch 39/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0438 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0459
# Epoch 40/40
# 87/87 [==============================] - 1s 7ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0421 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0453
# 28/28 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0453
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0434
# Epoch 1/40
# 93/93 [==============================] - 5s 15ms/step - loss: 0.0243 - mse: 0.0243 - mae: 0.0929 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0588
# Epoch 2/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0546 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0477
# Epoch 3/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0492 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0453
# Epoch 4/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0454 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0461
# Epoch 5/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0447 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0420
# Epoch 6/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0471 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0393
# Epoch 7/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0425 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0397
# Epoch 8/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0417 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0396
# Epoch 9/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0420 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0395
# Epoch 10/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0408 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0433
# Epoch 11/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0403 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0413
# Epoch 12/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0407 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0402
# Epoch 13/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0394 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0443
# Epoch 14/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0394 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0536
# Epoch 15/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0427 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0420
# Epoch 16/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0406 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0392
# Epoch 17/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0410 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0411
# Epoch 18/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0400 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0386
# Epoch 19/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0399 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0390
# Epoch 20/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0373 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0432
# Epoch 21/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0387 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0394
# Epoch 22/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0380 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0421
# Epoch 23/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0388 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0394
# Epoch 24/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0411 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0394
# Epoch 25/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0376 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0422
# Epoch 26/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0384 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0388
# Epoch 27/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0372 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0441
# Epoch 28/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0419 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0400
# Epoch 29/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0378 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0427
# Epoch 30/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0384 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0428
# Epoch 31/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0391 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0386
# Epoch 32/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0363 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0410
# Epoch 33/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0372 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0389
# Epoch 34/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0370 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0392
# Epoch 35/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0390 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0400
# Epoch 36/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0378 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0430
# Epoch 37/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0371 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0421
# Epoch 38/40
# 93/93 [==============================] - 1s 8ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0382 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0382
# Epoch 39/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0342 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0407
# Epoch 40/40
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0374 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0426
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0426
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0456

# %% [markdown]
# # MSE

# %%
# print(train_mse)
# 以保留四位小数打印
print(np.round(train_mse, 5))
print(np.round(np.mean(train_mse),5))
# Out:
# [0.00095 0.00119 0.00312 0.00542 0.00522]
# 0.00318

# %%
# print(test_mes)
# 以保留四位小数打印
print(np.round(test_mes, 5))
print(np.round(np.mean(test_mes),5))
# Out:
# [0.00375 0.00336 0.00289 0.0033  0.00386]
# 0.00343
